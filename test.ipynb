# %% [markdown]
# ## Image feature discovery

# %%
from src.LLM_feature_gen.discover import discover_features_from_images
result = discover_features_from_images('discover_images')
print(result)

# %% [markdown]
# ## Image feature generation

# %%
from src.LLM_feature_gen.generate import generate_features_from_images
res = generate_features_from_images(root_folder="images")
print(res)

# %% [markdown]
# ## Text feature discovery

# %%
from src.LLM_feature_gen.discover import discover_features_from_texts
result = discover_features_from_texts('discover_texts')
print(result)

# %% [markdown]
# ## Text feature generation

# %%
from src.LLM_feature_gen.generate import generate_features_from_texts
res = generate_features_from_texts(root_folder="texts")
print(res)

# %% [markdown]
# ## Video feature discovery & generation

# %%
import json
from src.LLM_feature_gen.discover import discover_features_from_videos
from src.LLM_feature_gen.generate import generate_features_from_videos

features = discover_features_from_videos('images/politicka_videa')
print(json.dumps(features, indent=2, ensure_ascii=False))

results = generate_features_from_videos(
    root_folder="images",
    discovered_features=features
)
print(results)
# Out:
# Processing all 3 videos from folder 'politicka_videa'...
#  -> Analyzing: spd.mp4
#  -> Analyzing: stacilo (1).mp4
#  -> Analyzing: stan.mp4
#  -> Prepared 15 frames and 3 transcripts. Sending to LLM...
# Features saved to outputs\features_politicka_videa.json
# {
#   "proposed_features": [
#     {
#       "feature": "Setting type",
#       "description": "Some images are set in formal indoor environments (offices, studios), while others are outdoors (nature, public squares, hiking trails). This may reflect different thematic focuses or campaign styles.",
#       "possible_values": [
#         "formal indoor",
#         "urban outdoor",
#         "nature outdoor",
#         "public event stage"
#       ]
#     },
#     {
#       "feature": "Group activity type",
#       "description": "Groups are shown either in coordinated, symbolic gestures (hands together, raising flags) or in casual, everyday activities (hiking, gathering). This could indicate different approaches to group representation.",
#       "possible_values": [
#         "symbolic gesture",
#         "public speech",
#         "casual gathering",
#         "outdoor activity"
#       ]
#     },
#     {
#       "feature": "Dominant clothing style",
#       "description": "Some images feature formal attire (suits, ties, dresses), while others show casual or outdoor clothing (t-shirts, hiking gear). This may separate professional/political contexts from informal/community ones.",
#       "possible_values": [
#         "formal",
#         "semi-formal",
#         "casual",
#         "outdoor/hiking"
#       ]
#     },
#     {
#       "feature": "Presence of national symbols",
#       "description": "National flags and colors (Czech, Ukrainian) are visible in some images, while others lack such symbols. This may indicate a focus on national identity or international relations.",
#       "possible_values": [
#         "Czech flag",
#         "Ukrainian flag",
#         "no flag",
#         "multiple flags"
#       ]
#     },
#     {
#       "feature": "Textual message style",
#       "description": "Some frames use bold, directive slogans (e.g., 'VOLTE ZMĚNU', 'STAČILO!'), while others have more informational or invitational text. This reflects different communication strategies.",
#       "possible_values": [
#         "directive slogan",
#         "informational",
#         "invitation",
#         "no text"
#       ]
#     },
#     {
#       "feature": "Color palette of graphics",
#       "description": "Some images use strong, contrasting colors (red, blue, white), while others have softer, natural tones (greens, browns, yellows). This may relate to branding or thematic focus.",
#       "possible_values": [
#         "strong contrast",
#         "natural tones",
#         "mixed",
#         "minimal color"
#       ]
#     },
#     {
#       "feature": "Symbolic imagery",
#       "description": "Certain images use symbolic visuals (dove with olive branch, ammunition, handshake), while others focus on realistic scenes. Symbolic imagery may signal values or campaign themes.",
#       "possible_values": [
#         "peace symbol",
#         "military/industry symbol",
#         "unity gesture",
#         "no symbol"
#       ]
#     },
#     {
#       "feature": "Event context",
#       "description": "Some images depict organized public events (stage, microphones, audience), while others show private or small group activities (hiking, embracing). This may distinguish between public-facing and community-oriented approaches.",
#       "possible_values": [
#         "public event",
#         "private moment",
#         "community activity",
#         "no event"
#       ]
#     },
#     {
#       "feature": "Gender representation in group",
#       "description": "Groups vary in gender balance and visibility (mixed gender, predominantly male/female, equal representation). This may reflect different priorities or target audiences.",
#       "possible_values": [
#         "mixed gender",
#         "mostly male",
#         "mostly female",
#         "equal representation"
#       ]
#     },
#     {
#       "feature": "Use of props and objects",
#       "description": "Props such as microphones, flags, flowers, hiking backpacks, and umbrellas are present in some images, absent in others. The type of prop may indicate the nature of the activity or message.",
#       "possible_values": [
#         "microphone",
#         "flag",
#         "flower bouquet",
#         "backpack",
#         "umbrella",
#         "no prop"
#       ]
#     },
#     {
#       "feature": "Backdrop type",
#       "description": "Backdrops include urban architecture, nature, event banners, and plain studio backgrounds. The choice of backdrop may signal the intended message or audience.",
#       "possible_values": [
#         "urban architecture",
#         "nature/forest",
#         "event banner",
#         "plain studio"
#       ]
#     },
#     {
#       "feature": "Group formation and arrangement",
#       "description": "Groups are arranged in formal lines, circles, or casual clusters. The arrangement may reflect organizational style or campaign tone.",
#       "possible_values": [
#         "formal line",
#         "circle/unity gesture",
#         "casual cluster",
#         "individual focus"
#       ]
#     }
#   ]
# }
# politicka_videa: 100%|██████████| 3/3 [03:51<00:00, 77.04s/img]
# {'politicka_videa': 'outputs\\politicka_videa_feature_values.csv'}
