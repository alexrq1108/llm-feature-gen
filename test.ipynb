# %%
from src.LLM_feature_gen.discover import discover_features_from_images

# %%
result = discover_features_from_images('discover_images')
print(result)
# Out:
# Features saved to outputs/discovered_features_20251029_152629.json
# [{'proposed_features': [{'feature': 'presence of liquid broth', 'description': 'The image shows a dish with a visible liquid component, which may distinguish it from solid or dry food items.', 'possible_values': ['liquid broth present', 'no liquid broth']}, {'feature': 'visible vegetable pieces', 'description': 'There are clearly identifiable pieces of vegetables (such as green stalks and radish slices), which could separate dishes with visible vegetables from those without.', 'possible_values': ['vegetable pieces visible', 'no vegetable pieces visible']}, {'feature': 'served in dark bowl', 'description': 'The food is presented in a dark-colored bowl, which may be a distinguishing serving style compared to other types of containers.', 'possible_values': ['dark bowl', 'light bowl', 'no bowl']}, {'feature': 'reddish-orange coloration', 'description': 'The overall color of the dish is reddish-orange, possibly due to spices or broth, which could differentiate it from dishes with other dominant colors.', 'possible_values': ['reddish-orange', 'yellow', 'brown', 'green', 'white']}, {'feature': 'floating ingredients', 'description': 'Ingredients are floating in the liquid, which may distinguish soups or stews from other food types where ingredients are layered or mixed differently.', 'possible_values': ['ingredients floating', 'ingredients layered', 'ingredients mixed', 'no visible ingredients']}]}, {'features': 'To provide a complete and accurate analysis, I will need to see all 6 example images. Please upload the remaining images so I can examine them together and propose the key visual features that differentiate the two hidden categories.'}, {'proposed_features': [{'feature': 'presence of liquid base', 'description': 'The image shows a substantial amount of liquid, which may distinguish items that are primarily liquid-based from those that are solid or semi-solid.', 'possible_values': ['mostly liquid', 'mostly solid', 'mixed']}, {'feature': 'visible suspended ingredients', 'description': 'There are visible pieces of ingredients floating or suspended in the liquid, which could separate items with mixed components from those with uniform texture.', 'possible_values': ['ingredients suspended', 'uniform texture', 'layered']}, {'feature': 'container type', 'description': 'The contents are shown inside a metallic pot, which may differentiate items prepared or presented in cookware from those served in other types of containers.', 'possible_values': ['metal pot', 'ceramic bowl', 'plate', 'other']}, {'feature': 'surface appearance', 'description': 'The surface has a glossy, oily look with visible spices and shreds, which could distinguish between items with a clear, oily surface and those with matte or dry surfaces.', 'possible_values': ['oily/glossy', 'matte/dry', 'foamy', 'smooth']}]}, {'proposed_features': [{'feature': 'surface decoration style', 'description': 'The object displays intricate, repeating blue floral and leaf patterns on a white background, which may distinguish it from objects with plain or differently styled surfaces.', 'possible_values': ['intricate floral pattern', 'plain surface', 'geometric pattern', 'abstract pattern', 'no decoration']}, {'feature': 'presence of handles', 'description': 'The object has two decorative handles shaped like animal heads, which could separate it from objects without handles or with different handle styles.', 'possible_values': ['animal-shaped handles', 'no handles', 'loop handles', 'single handle', 'multiple handles']}, {'feature': 'overall shape', 'description': 'The object has a rounded, bulbous body with a narrow neck and flared rim, which may differ from objects with straight sides, flat tops, or other forms.', 'possible_values': ['bulbous with narrow neck', 'cylindrical', 'rectangular', 'flat', 'tapered']}, {'feature': 'material appearance', 'description': 'The glossy, smooth surface and painted design suggest a ceramic or porcelain material, which could distinguish it from objects ...
